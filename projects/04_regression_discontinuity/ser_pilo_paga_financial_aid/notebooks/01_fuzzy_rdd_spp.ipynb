# %% [markdown]
# # Fuzzy Regression Discontinuity — Ser Pilo Paga Financial Aid
#
# Working through this step by step.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("../data/raw/spp_fuzzy_rd.csv")

print(df.shape)
df.head()
# Out:
# (23132, 9)
#           X1  T  D  Y  icfes_female  icfes_age  icfes_urm  icfes_stratum  \
# 0  32.640000  1  1  1             1       16.0          1            1.0
# 1   0.070001  1  1  1             0       17.0          0            2.0
# 2  35.560000  1  1  1             0       15.0          0            NaN
# 3  -2.510001  0  0  0             0       16.0          0            1.0
# 4  -5.610000  0  0  0             0       17.0          0            3.0
#
#    icfes_famsize
# 0            6.0
# 1            4.0
# 2            NaN
# 3            2.0
# 4            4.0
